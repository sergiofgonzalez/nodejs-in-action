# %% [markdown]
# # Chapter 26 &mdash; Functional Programming
# ## [Part 0: Fundamentals](../part00-fundamentals/)
# ### Section 01: Intro to Abstract Data Types and Algorithms

# %% [markdown]
# ### Contents
#
# + Concepts on programming: resolution and implementation
# + Abstract Data types
# + Complexity of Algorithms: *Big O* notation

# %% [markdown]
# ### Programming
#
# *Programming* is part of the development of an application that solves a problem at hand.
#
# We can think of application creation as a two-step process:
# 1. Problem definition &mdash; where you describe what the application has to do
# 2. Program development &mdash; where you create a program that solves the problem at hand
#
# We can think of programming as the process of creation of a *program*.
#
# The following diagram depicts the process:
#
# ![Creation of a program](images/creation_of_a_program.png)
#
# + The resolution phase is the important one. In this phase we get the problem definition and get to an algorithm that details how the problem can be resolved.
# + The implementation phase consists in a *mere* translation of the algorithm in a series of statements that the computer can process.
#
# > An **algorithm** is a set of statements, each one with a clear meaning and that gets executed in a finite time. An algorithm always finishes after executing the a finite number of statements.
#
# There are several ways to express an algorithm:
# + flow diagrams
# + pseudocode

# %% [markdown]
# ### The resolution phase
#
# During the resolution phase, the problem is analyzed, and a solution to solve it is designed. Finally, the solution gets detailed as an algorithm.
#
# One of the techniques to deal with the resolution phase is known as *top-down design*. This technique, a variant of *divide and conquer* consists in carrying out an incremental process until you get to the final solution.
#
# When using this technique, the problem gets subdivided in smaller problems that are easier to address. Then each of the smaller problems gets subdivided until those are very easy to solve.

# %% [markdown]
# #### An example of the resolution phase
#
# Let's see how to apply the *top-down design* to solve a warehouse use case. Let's pretend that you get the requirement to build the list of products available in a warehouse, and categorized by `name`, `price` and `sku`. The list has to be displayed sorted by name, and displayed on the screen.
#
# Thus, problem at hand is *Produce product listing*, and following the *top-down design*, the first thing that we have to do is subdivide it in subproblems:
# + Produce product listing
#   + Get the product list
#   + Sort the product list by name
#   + Display the list on the screen
#
# Now we can subdivide further down:
#
# + Get the product list
#   + Initialize list holder
#   + while remaining products to fetch
#     + read product record
#     + add product record to the list
#
# This can be carried out indefinitely until we get to a set of statements that are easy to address. At that point, we can say we have finished the *resolution phase*.
#
# Note also, that the net result of this process is a *tree-like* structure that will hint at the *modular* structure of the program:
#
# ![Top-down resolution approach](images/top-down_resolution.png)

# %% [markdown]
# ### The process of abstraction
#
# Abstraction is what we use when we apply the *top-down design* process with iterative refining steps on which we drill-down on the details of a problem. In particular, this type of abstraction is known *procedural abstraction* to differentiate it from *data abstraction*.
#
# Note that in the process, we pay special attention to the *what* without minding about *how* (for now 😉).
#
# | NOTE: |
# | :---- |
# | The name of *procedural abstraction* comes from the old times of computer science, where a *procedure* was a part of a program that encapsulated all the statements that had to do with the same aspect of a program and that generalized the notion of an operator. A more appropriate name could be now *modular abstraction*. |
#
# Another type of abstractions have to do with the data. In the same way that we can do a *top-down design* for the operational part of a program, we can can do *top-down design* for the data concerns.
#
# *Data abstraction* also provides generalization and encapsulation. Data abstraction allows us to generalize data types, so that the same principles that apply to simple types such as numbers and strings can be applied to lists or trees.
#
# At the end:
# > A program = algorithm + data

# %% [markdown]
# ### Abstract Data Types
#
# The encapsulation of a data structure along with the set of operations that are allowed on the data structure is known as an *abstract data type* (or ADT for short).
#
# In short, an *abstract data type* is a lot like a class, but not necessarily a class. It is a more generic concept.
#
# Also, *ADTs* are implementation independent. *ADTs* are design phase artifacts that do not make assumptions on the language or runtime requirements.

# %% [markdown]
# #### Data Abstraction and data hierarchy
#
# High-level languages provide data types. Generally, a data type is a set of allowed values and a set of operations defined on those values. For example, strings can be used to represent a sequence of individual characters, they can be concatenated, split, transformed into uppercase, etc.
#
# On top of the data types, programming languages allow you to define classes and other data structures &mdash; those are used to group pieces of data that have to go together.
#
# On top of these artifacts is where we would define our *ADTs* &mdash; Math models with a set of operations defined on them, and a set of properties they satisfy. The *ADTs* are implementation independent in nature, although ultimately, to be useful in computer science, they will have to be implemented on a particular programming language.
#
# | NOTE: |
# | :---- |
# | Some examples of *ADTs* are lists, trees, graphs. |
#
# Note that typically, programming languages do not provide direct support for *ADTs*, and instead provide the basic tooling so that you can define them on elements that sit lower in the data hierarchy.
#
# ![Data Hierarchy](images/data_hierarchy.png)
#
# You can see in the diagram above that in the data hierarchy, each of the levels of the data hierarchy is supported by the lower levels. Note also that nothing prevents *ADTs* to get implemented on top of other *ADTs*.

# %% [markdown]
# #### An example of an abstract data type: Stack
#
# *Stacks* are very well known data structures in computer science. Those are also known as *LIFO* lists, as they follow a *last-in, first-out* approach when dealing with the elements they hold.
#
# *Stacks* also make very good *ADTs*, as can be defined as a set of elements along with a set of operations defined on them.
#
# Informally, the operations on the *stack* are.
# + createStack &mdash; creates an empty stack.
# + push &mdash; adds an element to the top of the stack.
# + pop &mdash; returns and removes the element in the top of the stack. (precondition: the stack must not be empty)
# + peek &mdash; returns the element in the top of the stack, without removing it (precondition: the stack must not be empty, postcondition: the stack remains the same)
# + isEmpty &mdash; returns a value indicating whether the stack is empty or not
#
#
# | NOTE: |
# | :---- |
# | Although this is an implementation concern, *ADTs* should always follow the principle of encapsulation and information hiding, to provide a strong guarantee to the consumers of the *ADT*. |

# %% [markdown]
# #### Advantages of abstract data types
#
# *ADTs* are like patterns for data &mdash; solving problems with *ADTs* ensure that the solution is not tightly coupled to a particular implementation. Also, when solving a problem with an *ADT* we can reimplement it without affecting the clients of the *ADT*, as they depend on the *ADT* operations, and not on the internal details of it.

# %% [markdown]
# #### Analysis level of abstract data types
#
# *ADTs* can be analyzed at different levels:
#
# + *logical level* &mdash; *ADT* definition in terms of data organization and operations
# + *implementation detail* &mdash; different possible implementations of a given *ADT*
# + *application detail* &mdash; examples of *ADT* that solve application problems

# %% [markdown]
# #### Formal specification of abstract data types
#
# *ADT* is a Math model, and as such there are many Math tooling we can use to define an *ADT* in the strictests of terms:
#  + algebraic representation
#  + formal lenguage specification
#
# Both are out of the scope of this section.

# %% [markdown]
# ### Objects
#
# Objects are closely related to *ADTs*.
#
# > an *object* is an *instance* of a *class*. A *class* specifies the behavior of the objects that will be created using the class as a template.
#
# The behavior of an *object* is done specifying what are the messages the objects understand, that is, the set of operations defined on the objects.
#
# *Objects* operations are known as *methods*, and its state is defined with *properties*.

# %% [markdown]
# ### Complexity of algorithms
#
# Many times you will face the situation in which many different algorithms solve the same problem. In such cases, you should apply certain criteria to choose which one you should use:
# + Readability and maintainability
# + Efficient use of resources
# + Reusability and modularity of the solution
# + Quality of documentation
# + Portability
# + ...
#
# All the individual criterion are relevant, and in general readability and maintainability and efficient use of resources should always be considered.

# %% [markdown]
# #### Execution time
#
# The execution time of a program depends on:
# + The number of times a certain statement is executed
# + The runtime/compiler in use, as a given high-level instruction can be compiled in many different ways
# + The type of hardware on which the program is being ran
#
# From the formal perspective of analysis of algorithms, we will focus on the first component: we will estimate the number of times each of the statements is executed and categorize the execution time according to that.
#
# Also, we will need to take into account the program or algorithm input size. For example, when dealing with sorting numbers, the execution time estimation will depend on whether we're sorting 10 or 10,000 numbers.
#
# Another factor to consider is how we are receiving the input. For example, a sorting algorithm will behave differently if the input is more or less sorted than if the input is completely randomized. In such cases, it is a common practice to categorize the use cases into:
# + worst case &mdash; when the input is given in a way that makes the execution time the longer
# + best case &mdash; when the input is given in a way that makes the execution time the smallest
# + average case &mdash; when the input is such that the estimation falls between the worst and best case
#
# In general, to categorize the execution time, we will use the **worst case** scenario, and use the $ T(n) $ notation, with $ n $ being the input size.

# %% [markdown]
# #### Order of magnitude of the execution time: *Big "O"* notation
#
# We will use the *Big "O"* notation to categorize and estimate the complexity of an algorithm or a piece of code.
#
# It can be formally defined as follows:
#
# > We say that $ T(n) $, the execution time of a piece of code, is in the same order of magnitude as $ f(n) $, and we write $ T(n) = O(n) $, if $ \exists \; c$ and $ n_0 $ such that $ T(n) \le c \cdot f(n), \; \forall \; n \ge n_0 $
#
# Thus, $ f(n) $ is an upper limit of execution time growth velocity of $ T(n) $, for a large $ n $.
#
# Let's grok this concept with a few examples.

# %% [markdown]
# ##### Exercise: Understanding the *Big "O"* notation
# Find the $ f(n) $, $ c $, $ n_0 $ and *Big "O"* notation for the following examples:
#
# a) $ T(n) = 3n $
#
# b) $ T(n) = n + 1024 $
#
# c) $ T(n) = 3n^2 + 5n + 3 $

# %% [markdown]
# Let's start with the first one:
#
# a) $ T(n) = 3n $
#
# In this example, the execution time of a piece of code is $ 3n $, that is, it grows linearly with the input so that for one element it takes 3 units of time, for two elements 6 units of time, etc.
#
# According to the formula, we need to find $ f(n) $, $ c $ and $ n_0 $ such that:
#
# $
# T(n) \le c \cdot f(n), \; \forall \; n \ge n_0
# $
#
# $
# 3n \le c \cdot f(n), \; \forall \; n \ge n_0 \\
# 3n \le 4 \cdot n, \; \forall \; n \ge 1 \\
# $
#
# Thus, $ f(n) = n $, $ c = 4 $ and $ n_0 = 1 $. The execution time of that piece of code can be written as $ O(n) $.

# %% [markdown]
# Now, we can apply the same technique for the second one:
#
# b) $ T(n) = n + 1024 $
#
# In this example, the execution time of a piece of code is $ n + 1024 $, that is, it grows linearly with the input with some displacement, so that for one element it takes 1025 units of time, for two elements 1026 units of time, etc.
#
# According to the formula, we need to find $ f(n) $, $ c $ and $ n_0 $ such that:
#
# $
# T(n) \le c \cdot f(n), \; \forall \; n \ge n_0
# $
#
# $
# n + 1024 \le 1025 \cdot n, \; \forall \; n \ge 1 \\
# $
#
# Thus, $ f(n) = n $, $ c = 1025 $ and $ n_0 = 1 $. The execution time of that piece of code can be written as $ O(n) $.
#
# | NOTE: |
# | :---- |
# | The order of magnitude of the execution time for $ 3n $ and $ n + 1024 $ is exactly the same. |

# %% [markdown]
# c) $ T(n) = 3n^2 + 5n + 3 $
#
# In this example, the execution time of a piece of code is a quadratic equation.
#
# According to the formula, we need to find $ f(n) $, $ c $ and $ n_0 $ such that:
#
# $
# T(n) \le c \cdot f(n), \; \forall \; n \ge n_0
# $
#
# $
# 3n^2 + 5n + 3 \le 11 \cdot n^2, \; \forall \; n \ge 1 \\
# $
#
# Thus, $ f(n) = n^2 $, $ c = 11 $ and $ n_0 = 1 $. The execution time of that piece of code can be written as $ O(n^2) $.

# %% [markdown]
# You see how when using the *Big "O"* notation, we're only concerned about the order of magnitude of the execution time, and do not care about displacements ($ n + 1024 $ is the same as $ n $), or scale ($ 3n $ is the same as $ n $).
#
# Thus, it is important to remember the following cheat sheet that compares the different orders of magnitude:
#
# $ O(1) \le O(log \, n) \le O(n) \le O(n \cdot log \, n) \le O(n^2) \le O(n^3) \le ... \le O(2^n) \le O(n!) $
#
# That is, constant execution time, will be more efficient than logarithmic growth, which will be more efficient than linear growth, which will be faster than quadratic growth, which will be faster than exponencial growth, which will be faster than factorial growth.

# %%
import numpy as np
import matplotlib.pyplot as plt
from math import log10, factorial, floor

fig, ax = plt.subplots()

plt.title(r'Comparing growth rates', fontsize=16)

ax.axhline(y=0, color='black')
ax.axvline(x=0, color='black')

# plotting the constant rate
def f1(x):
    return 1

def f2(x):
    if x > 0:
        return log(x)

def f3(x):
    return x

def f4(x):
    if x > 0:
        return x * log(x)    

def f5(x):
    return x ** 2

def f6(x):
    return x ** 3

def f7(x):
    return 2 ** x

def f8(x):
    return factorial(floor(x))  


xs = np.linspace(0, 10, 100)
plt.plot(xs, [f1(x) for x in xs], label=r'$ O(1)$')
plt.plot(xs, [f2(x) for x in xs], label=r'$ O(log \, n) $')
plt.plot(xs, [f3(x) for x in xs], label=r'$ O(n) $')
plt.plot(xs, [f4(x) for x in xs], label=r'$ O(n \cdot log \, n)$')
plt.plot(xs, [f5(x) for x in xs], label=r'$ O(n^2)$')
plt.plot(xs, [f6(x) for x in xs], label=r'$ O(n^3) $')
plt.plot(xs, [f7(x) for x in xs], label=r'$ O(2^n) $')
# plt.plot(xs, [f8(x) for x in xs], label=r'$ O(n!) $')

plt.xlabel(r'x')
plt.ylabel(r'y')
plt.legend(bbox_to_anchor=(1, 1))
plt.grid(True)
plt.show()

# %% [markdown]
# ##### Exercise: Calculating *Big "O"* for pieces of code
# Find the *Big "O"* for the following pieces of code:
#
# a) assignment
# ```javascript
# x = x + 1 $
# ```
#
# b) for loop
# ```javascript
# for (let i = 0; i < n; i++) {
#     x = x + 1;
# }
# ```
#
# c) nested loops
# ```javascript
# for (let i = 0; i < n; i++) {
#     for (let j = 0; j < m; j++) {
#         x = x + 1;
#     }
# }
# ```

# %% [markdown]
# a) assignment
# ```javascript
# x = x + 1 $
# ```
#
# Let's start with the simple assignment. We don't know how much this statement will take, but we know for sure that it does not depend in the input size, and that it is only executed once.
#
# As a result we can say:
# a) $ O(1) $

# %% [markdown]
# b) for loop
# ```javascript
# for (let i = 0; i < n; i++) {
#     x = x + 1;
# }
# ```
#
# This case is different, as larger $ n $ will make the loop to iterate a larger number of times.
#
# In particular, for a loop, $ T(n) = n \cdot T_{loop \, body} $.
#
# In our case, as we know that in this case the body is $ O(1) $, we can say:
#
# b) $ O(n) $

# %% [markdown]
# c) nested loops
# ```javascript
# for (let i = 0; i < n; i++) {
#     for (let j = 0; j < m; j++) {
#         x = x + 1;
#     }
# }
# ```
#
# We can use the rule for loops, and conclude:
#
# $ T(n) = n \cdot m $
#
# As a result, we can conclude:
#
# c) $ O(n^2) $

# %% [markdown]
# ##### Exercise: Calculating *Big "O"* for a realistic piece of code
# Calculate the *Big "O"* notation for the following implementation of the *Bubblesort* algorithm which sorts in ascending order a set of integers.

# %% [markdown]
# You can find a runnable example in [01 &mdash; Bubble sort](01-bubblesort), but the function that implements the algorithm is as follows:
#
# ```javascript
# export function bubbleSort(nums) {
#   const sortedNums = [...nums];
#   for (let i = 0; i < sortedNums.length - 1; i++) {
#     for (let j = sortedNums.length - 1; j >= i + 1; j--) {
#       if (sortedNums[j - 1] > sortedNums[j]) {
#         const temp = sortedNums[j - 1];
#         sortedNums[j - 1] = sortedNums[j];
#         sortedNums[j] = temp;
#       }
#     }
#   }
#   return sortedNums;
# }
# ```
#
# In the function, we have a statement that copies the input, which we can assume will cost $ n $, followed by a couple of nested loops $ O(n^2) $, which wrap three simple statements $ O(1) + O(1) + O(1) $.
#
# As a result, the execution time can be estimated as:
#
# $
# O(n) + O(n^2) + O(1) + O(1) + O(1) = O(n^2)
# $
#
# However, we can do it more formally, and compute the exact amount of operations that occur within the nested loops:
#
# + If the array to sort has a length = 2, the statements within the inner loop will execute once.
# + If the array to sort has a length = 3, the statements within the inner loop will execute 2 + 1 times
# + If the array to sort has a length = 4, the statements within the inner loop will execute 3 + 2 + 1 times
#
# Thus, in general, to sort an array of length $ n $
#
# $
# \displaystyle
# (n - 1) + (n - 2) + \ldots + 3 + 2 + 1 =
# \sum_{i=1}^{n-1}(n - i) = \frac{n \cdot (n - 1)}{2}
# $
#
# Which matches our *non-formal* assumption of *bubble sort* having a $ O(n^2) $ complexity.

# %% [markdown]
# #### General rules for computing execution time complexity
#
# Despite having followed the *formal* approach to compute the complexity, it is always easier to rely on this list of rules:
#
# + Simple statements are considered to be $ O(1) $. We consider simple statements assignments, arithmetic operations, comparisons, and read/write operations of primitives.
#
# + When dealing with a sequence of statements, the complexity will be the maximum complexity among the individual statements. For example, if we have two assignments and the copy of an array, the complexity will be $ O(n) $.
#
# + When dealing with branching, the complexity will be maximum complexity among all the different paths.
#
# + When dealing with loops, the complexity will be calculated as the complexity of the body plus the complexity of the termination condition, as the latter may involve complex operations such as a function invocation.
#
# + When invoking functions, the execution path must be traced, keeping track of the complexity within the body of the function that is called.
#
# It is also useful to remember this common summations:
#
# $
# \displaystyle \sum_{i=1}^{n}1 = n = O(n) \\
# \displaystyle \sum_{i=1}^{n}i = \frac{n \cdot (n + 1)}{2} = O(n^2) \\
# \displaystyle \sum_{i=1}^{n}i^2 = \frac{n \cdot (n + 1) \cdot (2n + 1)}{6} = O(n^3) \\
# $
#
# In general,
#
# $
# \displaystyle \sum_{i=1}^{n}i^k = O(n^{k + 1}) \\
# $
#
# You will face logarithmic complexity when a piece of the program for an input of size n executes, $ \frac{n}{2} $, $ \frac{n}{4} $, $ \frac{n}{8} $, ... 1 times.
#
# When an algorithm follows that pattern, we can assume that if for an input of size n it executes $ k $ times.
#
# $
# 2^k = n \Rightarrow k = log_2(n) \Rightarrow O(log \, n)
# $

# %% [markdown]
# ### Formal data structures and JavaScript
#
# This section presents some of the *formal* data structures and their characteristics in the JavaScript programming language.

# %% [markdown]
# #### Arrays
#
# In *classic* data structures theory:
# > **Arrays** implement homogeneous collections of elements.
#
# This means that all elements were meant to be of the same type. Elements are identified by its order, which is the position of the element in the array.
#
# The main operation found in *arrays* is the *access* to its elements using the following notation:
#
# ```javascript
# let numbers = [20, 12, 35, 11, 44];
#
# let firstNumber = numbers[0];
# let secondNumber = numbers[1];
# let lastNumber = numbers[numbers.length - 1];
# ```
#
# Note that arrays are indexed from `0` to `length - 1`.
#
# The complexity of the *access* operation in arrays is $ O(1) $. That is, it is independent of the number of elements of the array.

# %% [markdown]
# ##### Multidimensional arrays
#
# A multidimensional array is a data structure comprised of elements of a given type arranged in $ N $ dimensions. $ N $ indices are needed to access the individual elements:
#
# ```javascript
# let matrix3x3 = [[1, 2, 3], [4, 5, 6], [7, 8, 9]];
# let a23 = matrix3x3[1][2]; // => 6
# console.log(a23);
# ```
#
# Note that in the example we need two indices to access and individual element within the 2-dimensional array.

# %% [markdown]
# #### Record
#
# > A record is an heterogeneous, unsorted, collection of elements. Each element of the record is known as a *field*.
#
# The main operation on *records* is also the access to its fields.
#
# A record can be implemented as a JavaScript literal object:
#
# ```JavaScript
# const dateRecord = {
#     day: 5,
#     month: 'February',
#     year: 2021
# };
#
# const day = dateRecord.day; // => 5
# ```

# %% [markdown]
# #### Set
#
# > A set is a container of elements, in which the following operations are defined:
#
# + creation &mdash; allows us to build a set.
# + union &mdash; allows us to build a set consisting the elements of two existing sets.
# + intersection &mdash; allows us to build a set containing the elements that are found in two given sets.
# + in &mdash; let us check whether a given element is contained in a set.

# %% [markdown]
# ### You know you've mastered this chapter when...
#
# + You're aware that the creation of an application is a multi-step process involving the problem definition, and the program development.
#
# + You know that, in turn, a program development involves finding an algorithm that solves the problem at hand, followed by its implementation in a particular programming language.
#
# + You know that an algorithm is a set of statements, each one with a clear meaning, that gets executed in a finite time.
#
# + You understand, that the *resolution phase* of the program development is the truly important one. This is the one in which the problem is analyzed and solved.
#
# + You are aware that one of the most common techniques to deal with the resolution phase is the *top-down* design approach, in which a problem is subdivided into smaller problems that are easier to address. You understand that this process might involve several *recursive* steps in which those smaller problems might be further subdivided.
#
# + You're comfortable drawing trees to depict the *top-down* design approach to solve problems.
#
# ![Top-down resolution approach](images/top-down_resolution.png)
#
# + You're aware of the process of abstraction and how it applies to the logic of a program (procedural abstraction, such as the one used in *top-down* design) and to the data structures a program may manage (data abstraction).
#
# + You're comfortable describing a program as *algorithm + data*.
#
# + You're comfortable definining *Abstract Data Types* as design-time artifacts that group a set of operations along with an underlying data structure.
#
# + You understand the hierarchy of data in a programming runtime, and are aware of why the higher-level ADTs are not baked into the programming languages themselves (they are like *design patterns* &mdash; languages provides the necessary constructs for you to easily build them, but in general are not baked into the language).
#
# + You're aware that ADTs can be formally specified using Math.
#
# + You understand the different dimensions that can be used to categorize the complexity of algorithms.
#
# + You are aware that the most common one is the execution time, and that can be formalized by analyzing how many times a given statement is executed.
#
# + You understand that in many situations, the execution time of the algorithm will depend on the amount of inputs received and how (the arrangement) in which those are received.
#
# + You are comfortable using the *Big O* notation to categorize the complexity of an algorithm, and are aware of the basic rules:
#   + $ O(1) \le O(log \, n) \le O(n) \le O(n \cdot log \, n) \le O(n^2) \le O(n^3) \le ... \le O(2^n) \le O(n!) $
#   + Simple statements are considered to be $ O(1) $. We consider simple statements assignments, arithmetic operations, comparisons, and read/write operations of primitives.
#
#   + When dealing with a sequence of statements, the complexity will be the maximum complexity among the individual statements. For example, if we have two assignments and the copy of an array, the complexity will be $ O(n) $.
#
#   + When dealing with branching, the complexity will be maximum complexity among all the different paths.
#
#   + When dealing with loops, the complexity will be calculated as the complexity of the body plus the complexity of the termination condition, as the latter may involve complex operations such as a function invocation.
#
#   + When invoking functions, the execution path must be traced, keeping track of the complexity within the body of the function that is called.
#
#   + It is also useful to remember this common summations:
#
# $$
# \displaystyle \sum_{i=1}^{n}1 = n = O(n) \\
# \displaystyle \sum_{i=1}^{n}i = \frac{n \cdot (n + 1)}{2} = O(n^2) \\
# \displaystyle \sum_{i=1}^{n}i^2 = \frac{n \cdot (n + 1) \cdot (2n + 1)}{6} = O(n^3) \\
# $$
#
#   + In general,
#
# $$
# \displaystyle \sum_{i=1}^{n}i^k = O(n^{k + 1}) \\
# $$
#
#   + You will face logarithmic complexity when a piece of the program for an input of size n executes, $ \frac{n}{2} $, $ \frac{n}{4} $, $ \frac{n}{8} $, ... 1 times. When an algorithm follows that pattern, we can assume that if for an input of size n it executes $ k $ times.
#
# $$
# 2^k = n \Rightarrow k = log_2(n) \Rightarrow O(log \, n)
# $$
